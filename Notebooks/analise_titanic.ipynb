# %% [markdown]
# # 🚢 Projeto: Análise Exploratória de Dados - Titanic
#
# ## 🎯 Objetivo
# Identificar fatores associados à sobrevivência dos passageiros do Titanic.
#
# ## 📊 Fonte dos Dados
# Base pública Titanic Dataset.
#
# ## 🧠 Pergunta Principal
# Quais fatores mais influenciaram a sobrevivência?

# %%
# !python -m pip install pandas matplotlib seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
